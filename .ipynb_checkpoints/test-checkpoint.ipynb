# %%
import pandas as pd

df1 = pd.read_excel(r'dataset\spam_ham_dataset_1.xls')
df1.head()
#bỏ các cột không cần thiết
#df1.drop('Unnamed: 0', axis=1, inplace = True)
#df1.columns = ['label', 'text', 'label_number']
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    20  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 21160= 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 21180  4 4 3 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
# 21200  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
# 21320= 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
# 21340  2 2 2 2 2 2 2 2 2 2 1
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# <ipython-input-6-6ae89c9e2b4a> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df1 = pd.read_excel(r'dataset\spam_ham_dataset_1.xls')
#       4 df1.head()
#       5 #bỏ các cột không cần thiết
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
# ...
